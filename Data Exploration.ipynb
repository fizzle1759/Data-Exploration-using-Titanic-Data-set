# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Exploration
# is the process of exploring the data to understand the pattern and structure of the dataset
#
# 1. Identify each of the variables in the dataset
# 2. Check and treat missing values
# 3. Check and treat duplicate entries
# 4. Variable selection
# 5. Variable creation
# 6. Data visualization(univariate,bivariate and multivariable analysis)

# %%
df = pd.read_csv("train.csv")

# %%
# Data Accesing

# %%
# print the first five row of the dadtaset
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# print the last five row of the dadtaset
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# print 10 random rows from the df
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 860          861         0       3            Hansen, Mr. Claus Peter    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 553          554         1       3  Leeni, Mr. Fahim ("Philip Zenni")    male
# 154          155         0       3              Olsen, Mr. Ole Martin    male
# 719          720         0       3       Johnson, Mr. Malkolm Joackim    male
# 512          513         1       1          McGough, Mr. James Robert    male
# 191          192         0       2              Carbines, Mr. William    male
# 795          796         0       2                 Otter, Mr. Richard    male
# 96            97         0       1          Goldschmidt, Mr. George B    male
# 482          483         0       3           Rouse, Mr. Richard Henry    male
#
#       Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 860  41.0      2      0     350026  14.1083   NaN        S
# 180   NaN      8      2   CA. 2343  69.5500   NaN        S
# 553  22.0      0      0       2620   7.2250   NaN        C
# 154   NaN      0      0  Fa 265302   7.3125   NaN        S
# 719  33.0      0      0     347062   7.7750   NaN        S
# 512  36.0      0      0   PC 17473  26.2875   E25        S
# 191  19.0      0      0      28424  13.0000   NaN        S
# 795  39.0      0      0      28213  13.0000   NaN        S
# 96   71.0      0      0   PC 17754  34.6542    A5        C
# 482  50.0      0      0   A/5 3594   8.0500   NaN        S

# %%
# show the summaryof the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# show the statistical summary of the dataframe
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# check for duplicate entries
df.duplicated().sum()
# Out:
# 0

# %%
# check for missing values
df.isna().sum()
# Out:
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age                0
# SibSp              0
# Parch              0
# Ticket             0
# Fare               0
# Cabin            687
# Embarked           0
# Cabin_address      0
# dtype: int64

# %%
# Data cleaning

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df.Age.median()
# Out:
# 28.0

# %%
median_age = df.Age.median()
df["Age"].fillna(median_age,inplace=True)

# %%
df["Cabin_address"]= df.Cabin.str[0]

# %%
df["Cabin_address"].mode([0])
# Out:
# 0    C
# Name: Cabin_address, dtype: object

# %%
most_frequent = df["Cabin_address"].mode()[0]

df["Cabin_address"].fillna(most_frequent,inplace=True)

# %%
most_frequent = df["Embarked"].mode()[0]

df["Embarked"].fillna(most_frequent,inplace=True)

# %%
split =lambda x : x.split()[1].strip(".").strip(",")

# %%
d = df.Name.apply(split)

d
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Name, Length: 891, dtype: object

# %%
f = []
for i in d:
    if i not in ["Mr", "Mrs", "Miss", "Master"," Dr", "Rev"]:
        i = "other"
    f.append(i)

# %%
d.index = f
f
# Out:
# ['Mr',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Master',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Master',
#  'Mr',
#  'other',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'other',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'other',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mrs',
#  'Master',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Master',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Master',
#  'Mr',
#  'Master',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Master',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Master',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Rev',
#  'Rev',
#  'Mrs',
#  'Mr',
#  'other',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Master',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Master',
#  'Master',
#  'Mrs',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'other',
#  'Master',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Master',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Master',
#  'Master',
#  'Miss',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Master',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Miss',
#  'other',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'other',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Rev',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Master',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Master',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'other',
#  'Mr',
#  'Mr',
#  'Mr',
#  'other',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Master',
#  'Miss',
#  'other',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'other',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr',
#  'other',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Master',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Master',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'other',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Mr',
#  'other',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'other',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Master',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mr',
#  'other',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Master',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'other',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'other',
#  'Mr',
#  'Master',
#  'Miss',
#  'Mr',
#  'Miss',
#  'other',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Master',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Master',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Miss',
#  'other',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'other',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'other',
#  'Mr',
#  'Master',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'other',
#  'Mr',
#  'Mrs',
#  'other',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mr',
#  'other',
#  'Miss',
#  'Mr',
#  'Mr',
#  'other',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Rev',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'other',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'other',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'other',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'other',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'other',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Master',
#  'other',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'other',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Master',
#  'other',
#  'Mr',
#  'Mrs',
#  'Master',
#  'Mr',
#  'Mr',
#  'Mr',
#  'other',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mrs',
#  'other',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Master',
#  'Master',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'other',
#  'Mrs',
#  'other',
#  'other',
#  'Mr',
#  'Mrs',
#  'Master',
#  'Master',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Master',
#  'Mrs',
#  'Mr',
#  'other',
#  'Mrs',
#  'Master',
#  'Mr',
#  'Mr',
#  'Master',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Master',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Rev',
#  'Mrs',
#  'Master',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Mrs',
#  'other',
#  'Mr',
#  'other',
#  'Master',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'other',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Rev',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr']

# %%
df["Title"] = f

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Cabin_address Title
# 0        0         A/5 21171   7.2500   NaN        S             C    Mr
# 1        0          PC 17599  71.2833   C85        C             C   Mrs
# 2        0  STON/O2. 3101282   7.9250   NaN        S             C  Miss
# 3        0            113803  53.1000  C123        S             C   Mrs
# 4        0            373450   8.0500   NaN        S             C    Mr
# ..     ...               ...      ...   ...      ...           ...   ...
# 886      0            211536  13.0000   NaN        S             C   Rev
# 887      0            112053  30.0000   B42        S             B  Miss
# 888      2        W./C. 6607  23.4500   NaN        S             C  Miss
# 889      0            111369  30.0000  C148        C             C    Mr
# 890      0            370376   7.7500   NaN        Q             C    Mr
#
# [891 rows x 14 columns]

# %%
df["family_no"] = df["SibSp"] + df["Parch"]

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Cabin_address Title  \
# 0        0         A/5 21171   7.2500   NaN        S             C    Mr
# 1        0          PC 17599  71.2833   C85        C             C   Mrs
# 2        0  STON/O2. 3101282   7.9250   NaN        S             C  Miss
# 3        0            113803  53.1000  C123        S             C   Mrs
# 4        0            373450   8.0500   NaN        S             C    Mr
# ..     ...               ...      ...   ...      ...           ...   ...
# 886      0            211536  13.0000   NaN        S             C   Rev
# 887      0            112053  30.0000   B42        S             B  Miss
# 888      2        W./C. 6607  23.4500   NaN        S             C  Miss
# 889      0            111369  30.0000  C148        C             C    Mr
# 890      0            370376   7.7500   NaN        Q             C    Mr
#
#      family_no
# 0            1
# 1            1
# 2            0
# 3            1
# 4            0
# ..         ...
# 886          0
# 887          0
# 888          3
# 889          0
# 890          0
#
# [891 rows x 15 columns]

# %%
df.drop(columns=["Name","SibSp","Parch","Ticket","Cabin"], inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age     Fare Embarked  \
# 0              1         0       3    male  22.0   7.2500        S
# 1              2         1       1  female  38.0  71.2833        C
# 2              3         1       3  female  26.0   7.9250        S
# 3              4         1       1  female  35.0  53.1000        S
# 4              5         0       3    male  35.0   8.0500        S
# ..           ...       ...     ...     ...   ...      ...      ...
# 886          887         0       2    male  27.0  13.0000        S
# 887          888         1       1  female  19.0  30.0000        S
# 888          889         0       3  female  28.0  23.4500        S
# 889          890         1       1    male  26.0  30.0000        C
# 890          891         0       3    male  32.0   7.7500        Q
#
#     Cabin_address Title  family_no
# 0               C    Mr          1
# 1               C   Mrs          1
# 2               C  Miss          0
# 3               C   Mrs          1
# 4               C    Mr          0
# ..            ...   ...        ...
# 886             C   Rev          0
# 887             B  Miss          0
# 888             C  Miss          3
# 889             C    Mr          0
# 890             C    Mr          0
#
# [891 rows x 10 columns]

# %% [markdown]
# # Univariate Analysis
# exploring variable/column one by one

# %%
gender_count= df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
gender_count= df.Survived.value_counts()
gender_count.index = ["dead","Survived"] # change the 0 and 1 to dead and survived

# %%
# pandas plot
gender_count.plot(kind="bar")
plt.title("Count of Dead and Survived",color="red")
plt.ylabel("Count")
plt.xlabel("Survived Rate")
plt.xticks(rotation=30)
plt.show()

# %%
pclass_count = df.Pclass.value_counts()
pclass_count.index = ["thirdclass", "firstclass","secondclass"]

# %%
pclass_count.plot(kind="bar")
plt.title("Count of Pclass",color="red")
plt.ylabel("Count")
plt.xlabel("pclass")
plt.xticks(rotation=30)
plt.show()

# %%
df["Age"].plot(kind="hist")
plt.title("Age Distribution",color="red")
plt.ylabel("Count")
plt.xlabel("Age")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# # Bi-variate Analysis
# exploring two variable to see the pattern they form

# %%
dead= df.query("Survived==0")["Pclass"].value_counts()
# Out:
# 3    372
# 2     97
# 1     80
# Name: Pclass, dtype: int64

# %%
alive=df.query("Survived==1")["Pclass"].value_counts()

# %%
dead= df.query("Survived==0")["Pclass"].value_counts()
df.query("Survived==1")["Pclass"].value_counts()
# Out:
# 1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64

# %%
i = pd.concat([dead,alive], axis =1, keys=["dead","Alive"])
i.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age     Fare Embarked  \
# 0              1         0       3    male  22.0   7.2500        S
# 1              2         1       1  female  38.0  71.2833        C
# 2              3         1       3  female  26.0   7.9250        S
# 3              4         1       1  female  35.0  53.1000        S
# 4              5         0       3    male  35.0   8.0500        S
# ..           ...       ...     ...     ...   ...      ...      ...
# 886          887         0       2    male  27.0  13.0000        S
# 887          888         1       1  female  19.0  30.0000        S
# 888          889         0       3  female  28.0  23.4500        S
# 889          890         1       1    male  26.0  30.0000        C
# 890          891         0       3    male  32.0   7.7500        Q
#
#     Cabin_address Title  family_no
# 0               C    Mr          1
# 1               C   Mrs          1
# 2               C  Miss          0
# 3               C   Mrs          1
# 4               C    Mr          0
# ..            ...   ...        ...
# 886             C   Rev          0
# 887             B  Miss          0
# 888             C  Miss          3
# 889             C    Mr          0
# 890             C    Mr          0
#
# [891 rows x 10 columns]

# %%
def barplot(feature):
    dead= df.query("Survived==0")[feature].value_counts()
    alive= df.query("Survived==1")[feature].value_counts()
    i = pd.concat([dead,alive], axis =1, keys=["dead","Alive"])
    i.plot(kind="bar")
    plt.title(f"count of {feature} per survival rate")
    plt.ylabel("counts")
    plt.xlabel(f"{feature}")
    plt.show()

# %%
barplot("Sex")

# %%
barplot("Embarked")

# %%
facet = sns.FacetGrid(df,hue="Survived",aspect=5)
facet.map(sns.kdeplot,"Age",shade=True)
plt.legend()
plt.show()
